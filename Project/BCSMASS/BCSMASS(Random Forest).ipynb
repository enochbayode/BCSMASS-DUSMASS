# %% [markdown]
# # Random forest model

# %% [markdown]
# ## Importing the required library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# ## importing the dataset

# %%
file_path = r'C:\Users\Administrator\Downloads\Project\BCSMASS\BCSMASS 2010-2023.xlsx'
dataset = pd.read_excel(file_path)

# %% [markdown]
# ## selecting the input columns

# %%
input_cols = ['BCSMASS 2011', 'BCSMASS 2012', 'BCSMASS 2013', 'BCSMASS 2014',
                 'BCSMASS 2015', 'BCSMASS 2016', 'BCSMASS 2017', 'BCSMASS 2018', 'BCSMASS 2019', 'BCSMASS 2020',
                     ]

# %% [markdown]
# ## selecting the output columns

# %%
output_cols = 'BCSMASS 2021'

# %% [markdown]
# ## specifying the dependent and inpendent variables

# %%
X = dataset[input_cols].values
y = dataset[output_cols].values

# %% [markdown]
# ## normalizing the dataset for X and y variable

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

# %% [markdown]
# ## split dataset into train and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=0)

# %% [markdown]
# ## using the Random forest model

# %%
from sklearn.ensemble import RandomForestRegressor
#initialize the model and use it 
model = RandomForestRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# ## Fit the model

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## model prediction

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# %% [markdown]
# ## checking the model result for training set

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
Train_R_squared = r2_score(y_train, train_predictions)
Train_MSR = mean_squared_error(y_train, train_predictions)
Train_MAE = mean_absolute_error(y_train, train_predictions)

# %%
print ('Train_R-squared score', Train_R_squared)
print ('Train_Mean squared error', Train_MSR)
print ('Train_Mean absolute error', Train_MAE)
# Out:
# Train_R-squared score 0.9723503067660864
# Train_Mean squared error 0.000248874833268957
# Train_Mean absolute error 0.009811457851036333

# %% [markdown]
# ## checking the model result for test set

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
Test_R_squared = r2_score(y_test, test_predictions)
Test_MSR = mean_squared_error(y_test, test_predictions)
Test_MAE = mean_absolute_error(y_test, test_predictions)

# %%
print ('Test_R-squared score', Test_R_squared)
print ('Test_Mean squared error', Test_MSR)
print ('Test_Mean absolute error', Test_MAE)
# Out:
# Test_R-squared score 0.7874732624828108
# Test_Mean squared error 0.0016628368942961593
# Test_Mean absolute error 0.025748486724086146

# %% [raw]
# Let's break down each of the metrics:
#
# 1. R-squared (R^2) value of 0.787:
#    - R-squared is a statistical measure that represents the proportion of the variance in the target variable that is explained by the independent variables in the model.
#    - An R-squared value of 0.787 means that approximately 78.7% of the variability in the target variable is explained by the independent variables in the model. In other words, the model captures about 78.7% of the patterns and trends in the data, which is considered a good fit.
#
# 2. Squared Error of 0.00166:
#    - Squared error, also known as mean squared error (MSE), measures the average squared difference between the actual values and the predicted values of the target variable.
#    - A squared error of 0.00166 indicates that, on average, the squared difference between the actual and predicted values is very small, suggesting that the model's predictions are generally close to the actual values.
#
# 3. Absolute Error of 0.0257:
#    - Absolute error, also known as mean absolute error (MAE), measures the average absolute difference between the actual values and the predicted values of the target variable.
#    - An absolute error of 0.0257 indicates that, on average, the absolute difference between the actual and predicted values is relatively small, suggesting that the model's predictions are generally accurate.
#
# In summary, the R-squared value indicates that the model explains a significant portion of the variability in the target variable, while the squared error and absolute error metrics suggest that the model's predictions are generally close to the actual values with small errors. Overall, these metrics indicate that the model performs well on the test set data.

# %% [markdown]
# ## Visualising the Random Forest Regression results (higher resolution)

# %%
fig = plt.figure(figsize=(10,8))
plt.scatter(y_test, test_predictions, alpha=0.5, label = 'Actual Values vs Predicted Values')

plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 
         linestyle='--', color='red', linewidth=2, label = 'Fit line y = 0.1054*x + 0.0243')

plt.title('Random Forest Regression: Actual BCSMASS vs. Predicted BCSMASS')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values ')
plt.legend()
plt.show()
